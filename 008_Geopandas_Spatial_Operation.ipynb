# %% [markdown]
# # Geopandas - Spatial operations and overlays: creating new geometries

# %% [markdown]
# <div style='background:#B1F9E3; color:#000000' class= 'alert alert-box'>
#     <b>refer:</b>
#     <a href = ' https://github.com/jorisvandenbossche/geopandas-tutorial/blob/main/04-spatial-operations-overlays.ipynb'>
#     https://github.com/jorisvandenbossche/geopandas-tutorial/blob/main/04-spatial-operations-overlays.ipynb
#         </a>
# </div>

# %%
# Import geopandas
import geopandas as gpd

# %%
bu_gcs = gpd.read_file('builtup_footprint.shp')

# %%
bu_gcs.plot()
# Out:
# <Axes: >

# %%
bu_pcs = bu_gcs.to_crs("EPSG:32643")

# %%
bu_pcs.plot()
# Out:
# <Axes: >

# %%
bu_buff =bu_pcs.buffer(50)

# %%
bu_buff.plot()
# Out:
# <Axes: >
